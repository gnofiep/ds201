# %%
def Letter_grade(final_points):
 points = float(final_points)
 grade = str("")
 if points >= 92.5 and points <=100 :
     print("Your points: "+str(points)+ " Tour letter grade : A, good job!") 
     grade = str(A)
 elif points >= 82.5 and points <=92.4 :
     print("Your points: "+str(points)+ " Tour letter grade : B")
     grade = str(B)
 elif points >= 72.5 and points <=82.4:
     print("Your points: "+str(points)+ " Tour letter grade : C")
     grade = str(C)
 elif points >= 62.5 and points <=72.4 :
     print("Your points: "+str(points)+ " Tour letter grade : D")
     grade = str(D)
 else:
     print("Your points: "+str(points)+ " Tour letter grade : F, Sorry you fail")
     grade = str(F)

    
inp = input("What is your final point?")
Letter_grade(inp)
print("Do you have more grades to calculate?")
answer = input()
while answer is 'y'or 'Y'or'Yes' or 'yes' or 'I do':
    Letter_grade = input("What is your final point?")
print("Grande report complete, Your final letter grade is "+ grade )

# %%
def Letter_grade(final_points):
 points = float(final_points)
 grade = ""
 if points >= 92.5 and points <=100 :
     print("Your points: "+str(points)+ " Tour letter grade : A, good job!") 
     grade = "A"
 elif points >= 82.5 and points <=92.4 :
     print("Your points: "+str(points)+ " Tour letter grade : B")
     grade = "B"
 elif points >= 72.5 and points <=82.4:
     print("Your points: "+str(points)+ " Tour letter grade : C")
     grade = "C"
 elif points >= 62.5 and points <=72.4 :
     print("Your points: "+str(points)+ " Tour letter grade : D")
     grade = "D"
 else:
     print("Your points: "+str(points)+ " Tour letter grade : F, Sorry you fail")
     grade = "F"

    
inp = input("What is your final point?")
Letter_grade(inp)
print("Do you have more grades to calculate?")
answer = input()
while answer is 'y'or 'Y'or'Yes' or 'yes' or 'I do':
 Letter_grade = input("What is your final point?")
 print("Do you have more grades to calculate?")
 answer = input()
print("Grande report complete, Your final letter grade is "+ grade )

# %%
def Letter_grade(final_points):
 points = float(final_points)
 grade = ""
 if points >= 92.5 and points <=100 :
     print("Your points: "+str(points)+ " Tour letter grade : A, good job!") 
     grade = "A"
     return grade
 elif points >= 82.5 and points <=92.4 :
     print("Your points: "+str(points)+ " Tour letter grade : B")
     grade = "B"
     return grade
 elif points >= 72.5 and points <=82.4:
     print("Your points: "+str(points)+ " Tour letter grade : C")
     grade = "C"
     return grade
 elif points >= 62.5 and points <=72.4 :
     print("Your points: "+str(points)+ " Tour letter grade : D")
     grade = "D"
     return grade
 else:
     print("Your points: "+str(points)+ " Tour letter grade : F, Sorry you fail")
     grade = "F"
     return grade

    
inp = input("What is your final point?")
Letter_grade(inp)
print("Do you have more grades to calculate?")
answer = input()
while answer is 'y'or 'Y'or'Yes' or 'yes' or 'I do':
 inp = input("What is your final point?")
 Letter_grade(inp)
 print("Do you have more grades to calculate?")
 answer = input()
 if answer is 'n' or 'N' or 'No' or 'no' or "I don't":
  print("Grande report complete, Your final letter grade is "+ grade )
break

# %%
def Letter_grade(final_points):
 points = float(final_points)
 grade = ""
 if points >= 92.5 and points <=100 :
     print("Your points: "+str(points)+ " Tour letter grade : A, good job!") 
     grade = "A"
     return grade
 elif points >= 82.5 and points <=92.4 :
     print("Your points: "+str(points)+ " Tour letter grade : B")
     grade = "B"
     return grade
 elif points >= 72.5 and points <=82.4:
     print("Your points: "+str(points)+ " Tour letter grade : C")
     grade = "C"
     return grade
 elif points >= 62.5 and points <=72.4 :
     print("Your points: "+str(points)+ " Tour letter grade : D")
     grade = "D"
     return grade
 else:
     print("Your points: "+str(points)+ " Tour letter grade : F, Sorry you fail")
     grade = "F"
     return grade

    
inp = input("What is your final point?")
Letter_grade(inp)
print("Do you have more grades to calculate?")
answer = input()
while answer in ['y', 'Y','Yes' , 'yes' , 'I do']:
 inp = input("What is your final point?")
 grade = Letter_grade(inp)
 print("Do you have more grades to calculate?")
 answer = input()
print("Grande report complete, Your final letter grade is "+ grade )
# Out:
# What is your final point?98
# Your points: 98.0 Tour letter grade : A, good job!
# Do you have more grades to calculate?
# y
# What is your final point?76
# Your points: 76.0 Tour letter grade : C
# Do you have more grades to calculate?
# n
# Grande report complete, Your final letter grade is C
