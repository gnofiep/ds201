# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
drinks = pd.read_csv("http://bit.ly/drinksbycountry")
drinks.head(5)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
type(drinks)
# Out:
# pandas.core.frame.DataFrame

# %%
drinks2 = drinks.groupby(['continent']).size().plot(kind = "bar")

# %%
drinks.groupby(['continent']).mean().plot(kind="bar")

# %%
drinks.groupby(['continent']).mean().plot(kind="bar", figsize=(10,8), rot =0, fontsize=8)

# %%
drinks.boxplot(column="beer_servings", by ="continent", figsize=(10,8), rot =0, fontsize=8)
