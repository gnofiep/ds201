# %%
import pandas as pd
import matplotlib.pyplot as plt
data_frame = pd.read_csv('Automobile_price_data_clean-f18.csv')
data_frame.head()
data_frame.boxplot(column="price", by ="body-style", figsize=(15,10), rot =45, fontsize=12)

# %%
data_frame.boxplot(column="price", by ="make", figsize=(15,10), rot =45, fontsize=12)
