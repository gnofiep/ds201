# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('USvideos.csv')

# %%
df.head(10)
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
# 5  gHZ1Qz0KiKM      17.14.11
# 6  39idVpFF7NQ      17.14.11
# 7  nc99ccSXST0      17.14.11
# 8  jr9QtXwC9vc      17.14.11
# 9  TUmyygCMMGA      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
# 5                              2 Weeks with iPhone X               iJustine
# 6          Roy Moore & Jeff Sessions Cold Open - SNL    Saturday Night Live
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24951 entries, 0 to 24950
# Data columns (total 16 columns):
# video_id                  24951 non-null object
# trending_date             24951 non-null object
# title                     24951 non-null object
# channel_title             24951 non-null object
# category_id               24951 non-null int64
# publish_time              24951 non-null object
# tags                      24951 non-null object
# views                     24951 non-null int64
# likes                     24951 non-null int64
# dislikes                  24951 non-null int64
# comment_count             24951 non-null int64
# thumbnail_link            24951 non-null object
# comments_disabled         24951 non-null bool
# ratings_disabled          24951 non-null bool
# video_error_or_removed    24951 non-null bool
# description               24507 non-null object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  24951.000000  2.495100e+04  2.495100e+04  2.495100e+04   2.495100e+04
# mean      20.095187  1.343969e+06  4.698547e+04  2.815263e+03   5.954496e+03
# std        7.585898  4.218125e+06  1.502137e+05  3.450366e+04   3.221468e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  1.282135e+05  2.598000e+03  1.150000e+02   3.545000e+02
# 50%       24.000000  3.803930e+05  1.074500e+04  3.790000e+02   1.165000e+03
# 75%       25.000000  1.120026e+06  3.258850e+04  1.233000e+03   3.655000e+03
# max       43.000000  1.493761e+08  3.093544e+06  1.674420e+06   1.361580e+06

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
data = df[['views','likes','category_id']]
Correlation = data.corr(method='pearson')
Correlation
# Out:
#                 views     likes  category_id
# views        1.000000  0.794761    -0.126534
# likes        0.794761  1.000000    -0.134979
# category_id -0.126534 -0.134979     1.000000

# %%
df.nlargest(100,'views')
# Out:
#           video_id trending_date  \
# 6181   FlsCjmMhFmw      17.14.12
# 5935   FlsCjmMhFmw      17.13.12
# 5699   FlsCjmMhFmw      17.12.12
# 5452   FlsCjmMhFmw      17.11.12
# 2587   TyHvyGVs42U      17.26.11
# 5236   FlsCjmMhFmw      17.10.12
# 4997   6ZfuNTqbHE8      17.08.12
# 2365   TyHvyGVs42U      17.25.11
# 4743   6ZfuNTqbHE8      17.07.12
# 4514   6ZfuNTqbHE8      17.06.12
# 4276   6ZfuNTqbHE8      17.05.12
# 2151   TyHvyGVs42U      17.24.11
# 4043   6ZfuNTqbHE8      17.04.12
# 5020   FlsCjmMhFmw      17.09.12
# 3818   6ZfuNTqbHE8      17.03.12
# 1950   TyHvyGVs42U      17.23.11
# 24890  -BQJo3vK8O8      18.20.03
# 3605   6ZfuNTqbHE8      17.02.12
# 24673  -BQJo3vK8O8      18.19.03
# 24465  -BQJo3vK8O8      18.18.03
# 11585  LsoLEjrDogU      18.12.01
# 1704   TyHvyGVs42U      17.22.11
# 3400   6ZfuNTqbHE8      17.01.12
# 18150  BhIEIO0vaBE      18.14.02
# 24256  -BQJo3vK8O8      18.17.03
# 17916  BhIEIO0vaBE      18.13.02
# 17716  BhIEIO0vaBE      18.12.02
# ...

# %%
df.nlargest(10,['views','likes'])
# Out:
#          video_id trending_date  \
# 6181  FlsCjmMhFmw      17.14.12
# 5935  FlsCjmMhFmw      17.13.12
# 5699  FlsCjmMhFmw      17.12.12
# 5452  FlsCjmMhFmw      17.11.12
# 2587  TyHvyGVs42U      17.26.11
# 5236  FlsCjmMhFmw      17.10.12
# 4997  6ZfuNTqbHE8      17.08.12
# 2365  TyHvyGVs42U      17.25.11
# 4743  6ZfuNTqbHE8      17.07.12
# 4514  6ZfuNTqbHE8      17.06.12
#
#                                                   title         channel_title  \
# 6181  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 5935  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 5699  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 5452  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# 2587          Luis Fonsi, Demi Lovato - Échame La Culpa         LuisFonsiVEVO
# 5236  YouTube Rewind: The Shape of 2017 | #YouTubeRe...     YouTube Spotlight
# ...

# %%
df_top100views = df.nlargest(100,'views')

# %%
df_top100views
# Out:
#           video_id trending_date  \
# 6181   FlsCjmMhFmw      17.14.12
# 5935   FlsCjmMhFmw      17.13.12
# 5699   FlsCjmMhFmw      17.12.12
# 5452   FlsCjmMhFmw      17.11.12
# 2587   TyHvyGVs42U      17.26.11
# 5236   FlsCjmMhFmw      17.10.12
# 4997   6ZfuNTqbHE8      17.08.12
# 2365   TyHvyGVs42U      17.25.11
# 4743   6ZfuNTqbHE8      17.07.12
# 4514   6ZfuNTqbHE8      17.06.12
# 4276   6ZfuNTqbHE8      17.05.12
# 2151   TyHvyGVs42U      17.24.11
# 4043   6ZfuNTqbHE8      17.04.12
# 5020   FlsCjmMhFmw      17.09.12
# 3818   6ZfuNTqbHE8      17.03.12
# 1950   TyHvyGVs42U      17.23.11
# 24890  -BQJo3vK8O8      18.20.03
# 3605   6ZfuNTqbHE8      17.02.12
# 24673  -BQJo3vK8O8      18.19.03
# 24465  -BQJo3vK8O8      18.18.03
# 11585  LsoLEjrDogU      18.12.01
# 1704   TyHvyGVs42U      17.22.11
# 3400   6ZfuNTqbHE8      17.01.12
# 18150  BhIEIO0vaBE      18.14.02
# 24256  -BQJo3vK8O8      18.17.03
# 17916  BhIEIO0vaBE      18.13.02
# 17716  BhIEIO0vaBE      18.12.02
# ...

# %%
sns.pairplot(df[['category_id','views','likes']],hue='category_id')

# %%
sns.pairplot(df_top100views[['category_id','views','likes']],hue='category_id')

# %%
# The differences between the two plots are as the following:
# there are less category_id in the top 100 views videos compare to the overall videos
# category_id act as the control varible in these charts, it manipulate 
# the views and likes. 
# there are more bars columns showing in views and likes for the top 100 videos 
# compare to the first plot.
# The higher the likes, the higher the views for both plots.
